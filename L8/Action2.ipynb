# %%
from surprise import KNNBasic, KNNWithMeans, KNNWithZScore, KNNBaseline
from surprise import Dataset, Reader
from surprise import accuracy
from surprise.model_selection import cross_validate
import pandas as pd

# 数据读取
reader = Reader(line_format='user item rating timestamp', sep=',', skip_lines=1)
data = Dataset.load_from_file('ratings.csv', reader=reader)

# 使用多种KNN模型
algo_1 = KNNBasic(k=50, sim_options={'user_based': False, 'verbose': 'True'})
algo_2 = KNNWithMeans(k=50, sim_options={'user_based': False, 'verbose': 'True'})
algo_3 = KNNWithZScore(k=50, sim_options={'user_based': False, 'verbose': 'True'})
algo_4 = KNNBaseline(k=50, sim_options={'user_based': False, 'verbose': 'True'},bsl_options={'method': 'als','n_epochs': 5,'reg_u': 12,'reg_i': 5})
algolist = [algo_1,algo_2,algo_3,algo_4]
algolist_name = ['KNNBasic', 'KNNWithMeans', 'KNNWithZScore', 'KNNBaseline']
n = 0

# 采用k折交叉验证(k=3)，输出每次计算的RMSE, MAE
for algo in algolist:
    print('正在使用',algolist_name[n],':')
    # 训练并预测
    algo.fit(trainset)
    cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
    n += 1
# Out:
# 正在使用 KNNBasic :
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.8958  0.8966  0.8939  0.8955  0.0011
# MAE (testset)     0.6891  0.6896  0.6884  0.6890  0.0005
# Fit time          20.80   20.61   22.39   21.27   0.80
# Test time         109.18  108.24  109.20  108.87  0.44
# 正在使用 KNNWithMeans :
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# ...
